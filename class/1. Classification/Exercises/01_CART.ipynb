# %% [markdown]
# # CART
#
# Aitor Díez Mateo - 72834331R

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Use the wine dataset to train a CART decision tree and visualize the result. Can you do the same with the diabetes dataset? What happens? What accuracy do you obtain with each dataset?

# %% [markdown]
# ## Wine dataset

# %% [markdown]
# Importing the libraries

# %%
from sklearn.datasets import load_wine
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd

# %% [markdown]
# Loading the data

# %%
wine = load_wine()
df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
df['target'] = wine.target.astype(str)
df['target'] = "class_"  +  df['target']

#Get the data
X = df.drop('target', axis=1)
y = df['target']

df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline   target
# ...

# %% [markdown]
# We need to split into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %% [markdown]
# Creation and training of the model

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %% [markdown]
# Now we make the predictions and compute the accuracy

# %%
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print(f"Obtained accuracy: {acc}")
# Out:
# Obtained accuracy: 0.8703703703703703

# %% [markdown]
# Finally, we visualize the tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.4230769230769231, 0.9, 'x[12] <= 787.5\ngini = 0.664\nsamples = 124\nvalue = [44, 44, 36]'),
#  Text(0.15384615384615385, 0.7, 'x[9] <= 4.02\ngini = 0.506\nsamples = 76\nvalue = [1.0, 42.0, 33.0]'),
#  Text(0.28846153846153844, 0.8, 'True  '),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(0.23076923076923078, 0.5, 'x[6] <= 2.02\ngini = 0.156\nsamples = 36\nvalue = [1, 2, 33]'),
#  Text(0.15384615384615385, 0.3, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]'),
#  Text(0.3076923076923077, 0.3, 'x[12] <= 706.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.23076923076923078, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.38461538461538464, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6923076923076923, 0.7, 'x[6] <= 2.165\ngini = 0.192\nsamples = 48\nvalue = [43, 2, 3]'),
#  Text(0.5576923076923077, 0.8, '  False'),
# ...

# %% [markdown]
# ## Diabetes dataset

# %% [markdown]
# Importing the libraries and loading the data

# %%
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target

#Get the data
X = df.drop('target', axis=1)
y = df['target']

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %% [markdown]
# We need to split into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %% [markdown]
# Creation and training of the model

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X_train, y_train)

# %% [markdown]
# Now we make the predictions and compute the accuracy

# %%
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print(f"Obtained accuracy: {acc}")
# Out:
# Obtained accuracy: 0.0

# %% [markdown]
# Obtained accuracy in this problem is 0.0 because the diabetes dataset contains a regression problem, not a classification one.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# What hyperparameters do we have for our algorithm? You can consult them in the documentation of DecisionTreeClassifier. Change them and see what are the results. Why do you think that they affect the obtained results? Which configuration offers the best results?

# %% [markdown]
# The hyperparameters that we can tune are:
# * criterion
# * splitter
# * max_depth
# * min_samples_split
# * min_samples_leaf
# * min_weight_fraction_leaf
# * max_features
# * random_state
# * max_leaf_nodes
# * min_impurity_decrease
# * class_weight
# * ccp_alpha
# * monotonic_cst
#
# Description of the hyperparameters can be found [here](https://scikit-learn.org/dev/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# Now we are going to change the hyperparameters and see the results of wine dataset again.

# %% [markdown]
# Loading the data

# %%
wine = load_wine()
df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
df['target'] = wine.target.astype(str)
df['target'] = "class_"  +  df['target']

#Get the data
X = df.drop('target', axis=1)
y = df['target']

df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline   target
# ...

# %% [markdown]
# We split the dataset into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %% [markdown]
# As there are many hyperparameters, we are going to try the hyperparameters "automatically" using [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html).

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Parameters we are going to try:

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [1, 2, 3],
    'max_features': [None, 'sqrt', 'log2']
}

# %% [markdown]
# Creation and training of the model

# %%
clf = tree.DecisionTreeClassifier()
grid_search = GridSearchCV(clf, param_grid, cv=5,scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\aitor\miniconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 4, 6],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %% [markdown]
# See the best parameters and the obtained accuracy

# %%
print(f"Obtained accuracy: {grid_search.best_score_}")
print(f"Best parameters: {grid_search.best_params_}")
# Out:
# Obtained accuracy: 0.9676666666666666
# Best parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}

# %% [markdown]
# Even if we have already said that diabetes dataset is a regression problem, we are going to try GridSearchCV with it in order we can improve our accuracy a bit.

# %% [markdown]
# Preparing the data

# %%
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
df['target'] = diabetes.target

#Get the data
X = df.drop('target', axis=1)
y = df['target']

# %% [markdown]
# We split the dataset into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# Creation and training of the model

# %%
clf = tree.DecisionTreeClassifier()
grid_search = GridSearchCV(clf, param_grid, cv=5,scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\aitor\miniconda3\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 4, 6],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %% [markdown]
# See the best parameters and the obtained accuracy

# %%
print(f"Obtained accuracy: {grid_search.best_score_}")
print(f"Best parameters: {grid_search.best_params_}")
# Out:
# Obtained accuracy: 0.022696177062374246
# Best parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}

# %% [markdown]
# We can observe that the accuracy has increased a bit.

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Use the CSV file used in the previous dataset and create a CART tree to classify it. Visualize the results. Why do you think that you obtain that accuracy?

# %% [markdown]
# Loading the data

# %%
df = pd.read_csv("C:/Users/aitor/PycharmProjects/ML-Class/data/03_a_tree_dataset.csv", names=["Outlook","Humidity","Wind","PlayTennis"])
df.head()
# Out:
#   Outlook Humidity    Wind PlayTennis
# 0    rain   normal  strong        yes
# 1    rain   normal  strong        yes
# 2    rain   normal  strong        yes
# 3    rain     high    weak        yes
# 4    rain   normal  strong         no

# %% [markdown]
# Nonetheless, we need to convert columns to numerical values. We will use dummy columns.

# %%
df = pd.get_dummies(df,columns=["Outlook","Humidity","Wind"])
df.head()
# Out:
#   PlayTennis  Outlook_overcast  Outlook_rain  Outlook_sunny  Humidity_high  \
# 0        yes             False          True          False          False
# 1        yes             False          True          False          False
# 2        yes             False          True          False          False
# 3        yes             False          True          False           True
# 4         no             False          True          False          False
#
#    Humidity_normal  Wind_strong  Wind_weak
# 0             True         True      False
# 1             True         True      False
# 2             True         True      False
# 3            False        False       True
# 4             True         True      False

# %% [markdown]
# We split the dataset into train and test

# %%
X = df.drop('PlayTennis', axis=1)
y = df['PlayTennis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# Creation and training of the model

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %% [markdown]
# Now we make the predictions and compute the accuracy

# %%
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Obtained accuracy: {acc}")
# Out:
# Obtained accuracy: 0.445

# %% [markdown]
# Finally, we visualize the tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5869565217391305, 0.9, 'x[2] <= 0.5\ngini = 0.5\nsamples = 800\nvalue = [394.0, 406.0]'),
#  Text(0.34782608695652173, 0.7, 'x[5] <= 0.5\ngini = 0.499\nsamples = 527\nvalue = [277, 250]'),
#  Text(0.4673913043478261, 0.8, 'True  '),
#  Text(0.17391304347826086, 0.5, 'x[0] <= 0.5\ngini = 0.496\nsamples = 262\nvalue = [143, 119]'),
#  Text(0.08695652173913043, 0.3, 'x[3] <= 0.5\ngini = 0.492\nsamples = 112\nvalue = [63, 49]'),
#  Text(0.043478260869565216, 0.1, 'gini = 0.5\nsamples = 53\nvalue = [27, 26]'),
#  Text(0.13043478260869565, 0.1, 'gini = 0.476\nsamples = 59\nvalue = [36, 23]'),
#  Text(0.2608695652173913, 0.3, 'x[4] <= 0.5\ngini = 0.498\nsamples = 150\nvalue = [80, 70]'),
#  Text(0.21739130434782608, 0.1, 'gini = 0.499\nsamples = 69\nvalue = [33, 36]'),
#  Text(0.30434782608695654, 0.1, 'gini = 0.487\nsamples = 81\nvalue = [47, 34]'),
#  Text(0.5217391304347826, 0.5, 'x[3] <= 0.5\ngini = 0.5\nsamples = 265\nvalue = [134, 131]'),
# ...

# %% [markdown]
# As the accuracy is quite low, we are going to use GridSearchCV to find the best hyperparameters.

# %%
clf = tree.DecisionTreeClassifier()
grid_search = GridSearchCV(clf, param_grid, cv=5,scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 4, 6],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %% [markdown]
# See the best parameters and the obtained accuracy

# %%
print(f"Obtained accuracy: {grid_search.best_score_}")
print(f"Best parameters: {grid_search.best_params_}")
# Out:
# Obtained accuracy: 0.50625
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}

# %% [markdown]
# We can observe that the accuracy is still quite low. This is because it contains independent and identically distributed random variables. This means that the variables are not correlated with each other, and the model cannot learn from them.
